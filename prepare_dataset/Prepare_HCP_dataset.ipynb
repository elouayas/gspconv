# %% [markdown]
# Author : Yassine El Ouahidi, inspired by Myriam Bontonou
#
# Using the IBC dataset, we can define a classification problem where a class is a condition studied during a fMRI task (e.g. *audio sentence*, *speech sound*, *face gender*, *reward*, *left hand*...). The data samples are elementary contrast maps associated with a condition studied during a task performed by a subject.
#
# Broadly speaking, an elementary contrast map is a 3D volume. Each voxel (elementary volume) represents the activation of an area of the brain with respect to the studied condition.
#
# In this notebook, we prepare a **benchmark** where the **classes** are **conditions** and the **data samples** are **elementary contrast maps**.

# %% [markdown]
# # Run this notebook to prepare the benchmark for your own work.

# %%
## TO UPDATE ##
# Directory where the IBC dataset will be downloaded.
data_dir = '/users/local/nilearn_data/'

# Directory where the file Glasser_masker.nii.gz is stored.
path_Glasser = '/homes/y17eloua/Projets/spectral_conv_neuroimaging_classification/dataset/Glasser_masker.nii.gz'

collection_id = 4337

# %% [markdown]
# If you are interested, you can look at the steps we went through, from the downloading of the IBC dataset on NeuroVault to the split of the classes in a base dataset, a validation dataset and a novel dataset.

# %% [markdown]
# # 1. Download IBC dataset on NeuroVault.

# %%
import os
import numpy as np
from numpy import savez_compressed
from tqdm import tqdm
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from itertools import compress
import nibabel as nib
import nilearn
from nilearn.datasets import fetch_icbm152_brain_gm_mask  # load_mni152_brain_mask
from nilearn.input_data import NiftiLabelsMasker # NiftiMasker
from nilearn.image import load_img
from nilearn.plotting import view_img
from nilearn.regions import signals_to_img_labels
import wget

# %%
data = nilearn.datasets.fetch_neurovault_ids(collection_ids=[collection_id], data_dir=data_dir,mode='download_new')
# Out:
# Reading local neurovault data.
# Already fetched 1 image
# Already fetched 2 images
# Already fetched 3 images
# Already fetched 4 images
# Already fetched 5 images
# Already fetched 6 images
# Already fetched 7 images
# Already fetched 8 images
# Already fetched 9 images
# Already fetched 10 images
# Already fetched 11 images
# Already fetched 12 images
# Already fetched 13 images
# Already fetched 14 images
# Already fetched 15 images
# Already fetched 16 images
# Already fetched 17 images
# Already fetched 18 images
# Already fetched 19 images
# Already fetched 20 images
# Already fetched 21 images
# Already fetched 22 images
# Already fetched 23 images
# Already fetched 24 images
# Already fetched 25 images
# Already fetched 26 images
# Already fetched 27 images
# Already fetched 28 images
# Already fetched 29 images
# Already fetched 30 images
# Already fetched 31 images
# Already fetched 32 images
# Already fetched 33 images
# Already fetched 34 images
# Already fetched 35 images
# Already fetched 36 images
# Already fetched 37 images
# Already fetched 38 images
# Already fetched 39 images
# Already fetched 40 images
# Already fetched 41 images
# Already fetched 42 images
# Already fetched 43 images
# Already fetched 44 images
# Already fetched 45 images
# Already fetched 46 images
# Already fetched 47 images
# Already fetched 48 images
# Already fetched 49 images
# Already fetched 50 images
# Already fetched 51 images
# Already fetched 52 images
# Already fetched 53 images
# Already fetched 54 images
# Already fetched 55 images
# Already fetched 56 images
# Already fetched 57 images
# Already fetched 58 images
# Already fetched 59 images
# Already fetched 60 images
# Already fetched 61 images
# Already fetched 62 images
# Already fetched 63 images
# Already fetched 64 images
# Already fetched 65 images
# Already fetched 66 images
# Already fetched 67 images
# Already fetched 68 images
# Already fetched 69 images
# Already fetched 70 images
# Already fetched 71 images
# Already fetched 72 images
# Already fetched 73 images
# Already fetched 74 images
# Already fetched 75 images
# Already fetched 76 images
# Already fetched 77 images
# Already fetched 78 images
# Already fetched 79 images
# Already fetched 80 images
# Already fetched 81 images
# Already fetched 82 images
# Already fetched 83 images
# Already fetched 84 images
# Already fetched 85 images
# Already fetched 86 images
# Already fetched 87 images
# Already fetched 88 images
# Already fetched 89 images
# Already fetched 90 images
# Already fetched 91 images
# Already fetched 92 images
# Already fetched 93 images
# Already fetched 94 images
# Already fetched 95 images
# Already fetched 96 images
# Already fetched 97 images
# Already fetched 98 images
# Already fetched 99 images
# Already fetched 100 images
# Already fetched 101 images
# Already fetched 102 images
# Already fetched 103 images
# Already fetched 104 images
# Already fetched 105 images
# Already fetched 106 images
# Already fetched 107 images
# Already fetched 108 images
# Already fetched 109 images
# Already fetched 110 images
# Already fetched 111 images
# Already fetched 112 images
# Already fetched 113 images
# Already fetched 114 images
# Already fetched 115 images
# Already fetched 116 images
# Already fetched 117 images
# Already fetched 118 images
# Already fetched 119 images
# Already fetched 120 images
# Already fetched 121 images
# Already fetched 122 images
# Already fetched 123 images
# Already fetched 124 images
# Already fetched 125 images
# Already fetched 126 images
# Already fetched 127 images
# Already fetched 128 images
# Already fetched 129 images
# Already fetched 130 images
# Already fetched 131 images
# Already fetched 132 images
# Already fetched 133 images
# Already fetched 134 images
# Already fetched 135 images
# Already fetched 136 images
# Already fetched 137 images
# Already fetched 138 images
# Already fetched 139 images
# Already fetched 140 images
# Already fetched 141 images
# Already fetched 142 images
# Already fetched 143 images
# Already fetched 144 images
# Already fetched 145 images
# Already fetched 146 images
# Already fetched 147 images
# Already fetched 148 images
# Already fetched 149 images
# Already fetched 150 images
# Already fetched 151 images
# Already fetched 152 images
# Already fetched 153 images
# Already fetched 154 images
# Already fetched 155 images
# Already fetched 156 images
# Already fetched 157 images
# Already fetched 158 images
# Already fetched 159 images
# Already fetched 160 images
# Already fetched 161 images
# Already fetched 162 images
# Already fetched 163 images
# Already fetched 164 images
# Already fetched 165 images
# Already fetched 166 images
# Already fetched 167 images
# Already fetched 168 images
# Already fetched 169 images
# Already fetched 170 images
# Already fetched 171 images
# Already fetched 172 images
# Already fetched 173 images
# Already fetched 174 images
# Already fetched 175 images
# Already fetched 176 images
# Already fetched 177 images
# Already fetched 178 images
# Already fetched 179 images
# Already fetched 180 images
# Already fetched 181 images
# Already fetched 182 images
# Already fetched 183 images
# Already fetched 184 images
# Already fetched 185 images
# Already fetched 186 images
# Already fetched 187 images
# Already fetched 188 images
# Already fetched 189 images
# Already fetched 190 images
# Already fetched 191 images
# Already fetched 192 images
# Already fetched 193 images
# Already fetched 194 images
# Already fetched 195 images
# Already fetched 196 images
# Already fetched 197 images
# Already fetched 198 images
# Already fetched 199 images
# Already fetched 200 images
# Already fetched 201 images
# Already fetched 202 images
# Already fetched 203 images
# Already fetched 204 images
# Already fetched 205 images
# Already fetched 206 images
# Already fetched 207 images
# Already fetched 208 images
# Already fetched 209 images
# Already fetched 210 images
# Already fetched 211 images
# Already fetched 212 images
# Already fetched 213 images
# Already fetched 214 images
# Already fetched 215 images
# Already fetched 216 images
# Already fetched 217 images
# Already fetched 218 images
# Already fetched 219 images
# Already fetched 220 images
# Already fetched 221 images
# Already fetched 222 images
# Already fetched 223 images
# Already fetched 224 images
# Already fetched 225 images
# Already fetched 226 images
# Already fetched 227 images
# Already fetched 228 images
# Already fetched 229 images
# Already fetched 230 images
# Already fetched 231 images
# Already fetched 232 images
# Already fetched 233 images
# Already fetched 234 images
# Already fetched 235 images
# Already fetched 236 images
# Already fetched 237 images
# Already fetched 238 images
# Already fetched 239 images
# Already fetched 240 images
# Already fetched 241 images
# Already fetched 242 images
# Already fetched 243 images
# Already fetched 244 images
# Already fetched 245 images
# Already fetched 246 images
# Already fetched 247 images
# Already fetched 248 images
# Already fetched 249 images
# Already fetched 250 images
# Already fetched 251 images
# Already fetched 252 images
# Already fetched 253 images
# Already fetched 254 images
# Already fetched 255 images
# Already fetched 256 images
# Already fetched 257 images
# Already fetched 258 images
# Already fetched 259 images
# Already fetched 260 images
# Already fetched 261 images
# Already fetched 262 images
# Already fetched 263 images
# Already fetched 264 images
# Already fetched 265 images
# Already fetched 266 images
# Already fetched 267 images
# Already fetched 268 images
# Already fetched 269 images
# Already fetched 270 images
# Already fetched 271 images
# Already fetched 272 images
# Already fetched 273 images
# Already fetched 274 images
# Already fetched 275 images
# Already fetched 276 images
# Already fetched 277 images
# Already fetched 278 images
# Already fetched 279 images
# Already fetched 280 images
# Already fetched 281 images
# Already fetched 282 images
# Already fetched 283 images
# Already fetched 284 images
# Already fetched 285 images
# Already fetched 286 images
# Already fetched 287 images
# Already fetched 288 images
# Already fetched 289 images
# Already fetched 290 images
# Already fetched 291 images
# Already fetched 292 images
# Already fetched 293 images
# Already fetched 294 images
# Already fetched 295 images
# Already fetched 296 images
# Already fetched 297 images
# Already fetched 298 images
# Already fetched 299 images
# Already fetched 300 images
# Already fetched 301 images
# Already fetched 302 images
# Already fetched 303 images
# Already fetched 304 images
# Already fetched 305 images
# Already fetched 306 images
# Already fetched 307 images
# Already fetched 308 images
# Already fetched 309 images
# Already fetched 310 images
# Already fetched 311 images
# Already fetched 312 images
# Already fetched 313 images
# Already fetched 314 images
# Already fetched 315 images
# Already fetched 316 images
# Already fetched 317 images
# Already fetched 318 images
# Already fetched 319 images
# Already fetched 320 images
# Already fetched 321 images
# Already fetched 322 images
# Already fetched 323 images
# Already fetched 324 images
# Already fetched 325 images
# Already fetched 326 images
# Already fetched 327 images
# Already fetched 328 images
# Already fetched 329 images
# Already fetched 330 images
# Already fetched 331 images
# Already fetched 332 images
# Already fetched 333 images
# Already fetched 334 images
# Already fetched 335 images
# Already fetched 336 images
# Already fetched 337 images
# Already fetched 338 images
# Already fetched 339 images
# Already fetched 340 images
# Already fetched 341 images
# Already fetched 342 images
# Already fetched 343 images
# Already fetched 344 images
# Already fetched 345 images
# Already fetched 346 images
# Already fetched 347 images
# Already fetched 348 images
# Already fetched 349 images
# Already fetched 350 images
# Already fetched 351 images
# Already fetched 352 images
# Already fetched 353 images
# Already fetched 354 images
# Already fetched 355 images
# Already fetched 356 images
# Already fetched 357 images
# Already fetched 358 images
# Already fetched 359 images
# Already fetched 360 images
# Already fetched 361 images
# Already fetched 362 images
# Already fetched 363 images
# Already fetched 364 images
# Already fetched 365 images
# Already fetched 366 images
# Already fetched 367 images
# Already fetched 368 images
# Already fetched 369 images
# Already fetched 370 images
# Already fetched 371 images
# Already fetched 372 images
# Already fetched 373 images
# Already fetched 374 images
# Already fetched 375 images
# Already fetched 376 images
# Already fetched 377 images
# Already fetched 378 images
# Already fetched 379 images
# Already fetched 380 images
# Already fetched 381 images
# Already fetched 382 images
# Already fetched 383 images
# Already fetched 384 images
# Already fetched 385 images
# Already fetched 386 images
# Already fetched 387 images
# Already fetched 388 images
# Already fetched 389 images
# Already fetched 390 images
# Already fetched 391 images
# Already fetched 392 images
# Already fetched 393 images
# Already fetched 394 images
# Already fetched 395 images
# Already fetched 396 images
# Already fetched 397 images
# Already fetched 398 images
# Already fetched 399 images
# Already fetched 400 images
# Already fetched 401 images
# Already fetched 402 images
# Already fetched 403 images
# Already fetched 404 images
# Already fetched 405 images
# Already fetched 406 images
# Already fetched 407 images
# Already fetched 408 images
# Already fetched 409 images
# Already fetched 410 images
# Already fetched 411 images
# Already fetched 412 images
# Already fetched 413 images
# Already fetched 414 images
# Already fetched 415 images
# Already fetched 416 images
# Already fetched 417 images
# Already fetched 418 images
# Already fetched 419 images
# Already fetched 420 images
# Already fetched 421 images
# Already fetched 422 images
# Already fetched 423 images
# Already fetched 424 images
# Already fetched 425 images
# Already fetched 426 images
# Already fetched 427 images
# Already fetched 428 images
# Already fetched 429 images
# Already fetched 430 images
# Already fetched 431 images
# Already fetched 432 images
# Already fetched 433 images
# Already fetched 434 images
# Already fetched 435 images
# Already fetched 436 images
# Already fetched 437 images
# Already fetched 438 images
# Already fetched 439 images
# Already fetched 440 images
# Already fetched 441 images
# Already fetched 442 images
# Already fetched 443 images
# Already fetched 444 images
# Already fetched 445 images
# Already fetched 446 images
# Already fetched 447 images
# Already fetched 448 images
# Already fetched 449 images
# Already fetched 450 images
# Already fetched 451 images
# Already fetched 452 images
# Already fetched 453 images
# Already fetched 454 images
# Already fetched 455 images
# Already fetched 456 images
# Already fetched 457 images
# Already fetched 458 images
# Already fetched 459 images
# Already fetched 460 images
# Already fetched 461 images
# Already fetched 462 images
# Already fetched 463 images
# Already fetched 464 images
# Already fetched 465 images
# Already fetched 466 images
# Already fetched 467 images
# Already fetched 468 images
# Already fetched 469 images
# Already fetched 470 images
# Already fetched 471 images
# Already fetched 472 images
# Already fetched 473 images
# Already fetched 474 images
# Already fetched 475 images
# Already fetched 476 images
# Already fetched 477 images
# Already fetched 478 images
# Already fetched 479 images
# Already fetched 480 images
# Already fetched 481 images
# Already fetched 482 images
# Already fetched 483 images
# Already fetched 484 images
# Already fetched 485 images
# Already fetched 486 images
# Already fetched 487 images
# Already fetched 488 images
# Already fetched 489 images
# Already fetched 490 images
# Already fetched 491 images
# Already fetched 492 images
# Already fetched 493 images
# Already fetched 494 images
# Already fetched 495 images
# Already fetched 496 images
# Already fetched 497 images
# Already fetched 498 images
# Already fetched 499 images
# Already fetched 500 images
# Already fetched 501 images
# Already fetched 502 images
# Already fetched 503 images
# Already fetched 504 images
# Already fetched 505 images
# Already fetched 506 images
# Already fetched 507 images
# Already fetched 508 images
# Already fetched 509 images
# Already fetched 510 images
# Already fetched 511 images
# Already fetched 512 images
# Already fetched 513 images
# Already fetched 514 images
# Already fetched 515 images
# Already fetched 516 images
# Already fetched 517 images
# Already fetched 518 images
# Already fetched 519 images
# Already fetched 520 images
# Already fetched 521 images
# Already fetched 522 images
# Already fetched 523 images
# Already fetched 524 images
# Already fetched 525 images
# Already fetched 526 images
# Already fetched 527 images
# Already fetched 528 images
# Already fetched 529 images
# Already fetched 530 images
# Already fetched 531 images
# Already fetched 532 images
# Already fetched 533 images
# Already fetched 534 images
# Already fetched 535 images
# Already fetched 536 images
# Already fetched 537 images
# Already fetched 538 images
# Already fetched 539 images
# Already fetched 540 images
# Already fetched 541 images
# Already fetched 542 images
# Already fetched 543 images
# Already fetched 544 images
# Already fetched 545 images
# Already fetched 546 images
# Already fetched 547 images
# Already fetched 548 images
# Already fetched 549 images
# Already fetched 550 images
# Already fetched 551 images
# Already fetched 552 images
# Already fetched 553 images
# Already fetched 554 images
# Already fetched 555 images
# Already fetched 556 images
# Already fetched 557 images
# Already fetched 558 images
# Already fetched 559 images
# Already fetched 560 images
# Already fetched 561 images
# Already fetched 562 images
# Already fetched 563 images
# Already fetched 564 images
# Already fetched 565 images
# Already fetched 566 images
# Already fetched 567 images
# Already fetched 568 images
# Already fetched 569 images
# Already fetched 570 images
# Already fetched 571 images
# Already fetched 572 images
# Already fetched 573 images
# Already fetched 574 images
# Already fetched 575 images
# Already fetched 576 images
# Already fetched 577 images
# Already fetched 578 images
# Already fetched 579 images
# Already fetched 580 images
# Already fetched 581 images
# Already fetched 582 images
# Already fetched 583 images
# Already fetched 584 images
# Already fetched 585 images
# Already fetched 586 images
# Already fetched 587 images
# Already fetched 588 images
# Already fetched 589 images
# Already fetched 590 images
# Already fetched 591 images
# Already fetched 592 images
# Already fetched 593 images
# Already fetched 594 images
# Already fetched 595 images
# Already fetched 596 images
# Already fetched 597 images
# Already fetched 598 images
# Already fetched 599 images
# Already fetched 600 images
# Already fetched 601 images
# Already fetched 602 images
# Already fetched 603 images
# Already fetched 604 images
# Already fetched 605 images
# Already fetched 606 images
# Already fetched 607 images
# Already fetched 608 images
# Already fetched 609 images
# Already fetched 610 images
# Already fetched 611 images
# Already fetched 612 images
# Already fetched 613 images
# Already fetched 614 images
# Already fetched 615 images
# Already fetched 616 images
# Already fetched 617 images
# Already fetched 618 images
# Already fetched 619 images
# Already fetched 620 images
# Already fetched 621 images
# Already fetched 622 images
# Already fetched 623 images
# Already fetched 624 images
# Already fetched 625 images
# Already fetched 626 images
# Already fetched 627 images
# Already fetched 628 images
# Already fetched 629 images
# Already fetched 630 images
# Already fetched 631 images
# Already fetched 632 images
# Already fetched 633 images
# Already fetched 634 images
# Already fetched 635 images
# Already fetched 636 images
# Already fetched 637 images
# Already fetched 638 images
# Already fetched 639 images
# Already fetched 640 images
# Already fetched 641 images
# Already fetched 642 images
# Already fetched 643 images
# Already fetched 644 images
# Already fetched 645 images
# Already fetched 646 images
# Already fetched 647 images
# Already fetched 648 images
# Already fetched 649 images
# Already fetched 650 images
# Already fetched 651 images
# Already fetched 652 images
# Already fetched 653 images
# Already fetched 654 images
# Already fetched 655 images
# Already fetched 656 images
# Already fetched 657 images
# Already fetched 658 images
# Already fetched 659 images
# Already fetched 660 images
# Already fetched 661 images
# Already fetched 662 images
# Already fetched 663 images
# Already fetched 664 images
# Already fetched 665 images
# Already fetched 666 images
# Already fetched 667 images
# Already fetched 668 images
# Already fetched 669 images
# Already fetched 670 images
# Already fetched 671 images
# Already fetched 672 images
# Already fetched 673 images
# Already fetched 674 images
# Already fetched 675 images
# Already fetched 676 images
# Already fetched 677 images
# Already fetched 678 images
# Already fetched 679 images
# Already fetched 680 images
# Already fetched 681 images
# Already fetched 682 images
# Already fetched 683 images
# Already fetched 684 images
# Already fetched 685 images
# Already fetched 686 images
# Already fetched 687 images
# Already fetched 688 images
# Already fetched 689 images
# Already fetched 690 images
# Already fetched 691 images
# Already fetched 692 images
# Already fetched 693 images
# Already fetched 694 images
# Already fetched 695 images
# Already fetched 696 images
# Already fetched 697 images
# Already fetched 698 images
# Already fetched 699 images
# Already fetched 700 images
# Already fetched 701 images
# Already fetched 702 images
# Already fetched 703 images
# Already fetched 704 images
# Already fetched 705 images
# Already fetched 706 images
# Already fetched 707 images
# Already fetched 708 images
# Already fetched 709 images
# Already fetched 710 images
# Already fetched 711 images
# Already fetched 712 images
# Already fetched 713 images
# Already fetched 714 images
# Already fetched 715 images
# Already fetched 716 images
# Already fetched 717 images
# Already fetched 718 images
# Already fetched 719 images
# Already fetched 720 images
# Already fetched 721 images
# Already fetched 722 images
# Already fetched 723 images
# Already fetched 724 images
# Already fetched 725 images
# Already fetched 726 images
# Already fetched 727 images
# Already fetched 728 images
# Already fetched 729 images
# Already fetched 730 images
# Already fetched 731 images
# Already fetched 732 images
# Already fetched 733 images
# Already fetched 734 images
# Already fetched 735 images
# Already fetched 736 images
# Already fetched 737 images
# Already fetched 738 images
# Already fetched 739 images
# Already fetched 740 images
# Already fetched 741 images
# Already fetched 742 images
# Already fetched 743 images
# Already fetched 744 images
# Already fetched 745 images
# Already fetched 746 images
# Already fetched 747 images
# Already fetched 748 images
# Already fetched 749 images
# Already fetched 750 images
# Already fetched 751 images
# Already fetched 752 images
# Already fetched 753 images
# Already fetched 754 images
# Already fetched 755 images
# Already fetched 756 images
# Already fetched 757 images
# Already fetched 758 images
# Already fetched 759 images
# Already fetched 760 images
# Already fetched 761 images
# Already fetched 762 images
# Already fetched 763 images
# Already fetched 764 images
# Already fetched 765 images
# Already fetched 766 images
# Already fetched 767 images
# Already fetched 768 images
# Already fetched 769 images
# Already fetched 770 images
# Already fetched 771 images
# Already fetched 772 images
# Already fetched 773 images
# Already fetched 774 images
# Already fetched 775 images
# Already fetched 776 images
# Already fetched 777 images
# Already fetched 778 images
# Already fetched 779 images
# Already fetched 780 images
# Already fetched 781 images
# Already fetched 782 images
# Already fetched 783 images
# Already fetched 784 images
# Already fetched 785 images
# Already fetched 786 images
# Already fetched 787 images
# Already fetched 788 images
# Already fetched 789 images
# Already fetched 790 images
# Already fetched 791 images
# Already fetched 792 images
# Already fetched 793 images
# Already fetched 794 images
# Already fetched 795 images
# Already fetched 796 images
# Already fetched 797 images
# Already fetched 798 images
# Already fetched 799 images
# Already fetched 800 images
# Already fetched 801 images
# Already fetched 802 images
# Already fetched 803 images
# Already fetched 804 images
# Already fetched 805 images
# Already fetched 806 images
# Already fetched 807 images
# Already fetched 808 images
# Already fetched 809 images
# Already fetched 810 images
# Already fetched 811 images
# Already fetched 812 images
# Already fetched 813 images
# Already fetched 814 images
# Already fetched 815 images
# Already fetched 816 images
# Already fetched 817 images
# Already fetched 818 images
# Already fetched 819 images
# Already fetched 820 images
# Already fetched 821 images
# Already fetched 822 images
# Already fetched 823 images
# Already fetched 824 images
# Already fetched 825 images
# Already fetched 826 images
# Already fetched 827 images
# Already fetched 828 images
# Already fetched 829 images
# Already fetched 830 images
# Already fetched 831 images
# Already fetched 832 images
# Already fetched 833 images
# Already fetched 834 images
# Already fetched 835 images
# Already fetched 836 images
# Already fetched 837 images
# Already fetched 838 images
# Already fetched 839 images
# Already fetched 840 images
# Already fetched 841 images
# Already fetched 842 images
# Already fetched 843 images
# Already fetched 844 images
# Already fetched 845 images
# Already fetched 846 images
# Already fetched 847 images
# Already fetched 848 images
# Already fetched 849 images
# Already fetched 850 images
# Already fetched 851 images
# Already fetched 852 images
# Already fetched 853 images
# Already fetched 854 images
# Already fetched 855 images
# Already fetched 856 images
# Already fetched 857 images
# Already fetched 858 images
# Already fetched 859 images
# Already fetched 860 images
# Already fetched 861 images
# Already fetched 862 images
# Already fetched 863 images
# Already fetched 864 images
# Already fetched 865 images
# Already fetched 866 images
# Already fetched 867 images
# Already fetched 868 images
# Already fetched 869 images
# Already fetched 870 images
# Already fetched 871 images
# Already fetched 872 images
# Already fetched 873 images
# Already fetched 874 images
# Already fetched 875 images
# Already fetched 876 images
# Already fetched 877 images
# Already fetched 878 images
# Already fetched 879 images
# Already fetched 880 images
# Already fetched 881 images
# Already fetched 882 images
# Already fetched 883 images
# Already fetched 884 images
# Already fetched 885 images
# Already fetched 886 images
# Already fetched 887 images
# Already fetched 888 images
# Already fetched 889 images
# Already fetched 890 images
# Already fetched 891 images
# Already fetched 892 images
# Already fetched 893 images
# Already fetched 894 images
# Already fetched 895 images
# Already fetched 896 images
# Already fetched 897 images
# Already fetched 898 images
# Already fetched 899 images
# Already fetched 900 images
# Already fetched 901 images
# Already fetched 902 images
# Already fetched 903 images
# Already fetched 904 images
# Already fetched 905 images
# Already fetched 906 images
# Already fetched 907 images
# Already fetched 908 images
# Already fetched 909 images
# Already fetched 910 images
# Already fetched 911 images
# Already fetched 912 images
# Already fetched 913 images
# Already fetched 914 images
# Already fetched 915 images
# Already fetched 916 images
# Already fetched 917 images
# Already fetched 918 images
# Already fetched 919 images
# Already fetched 920 images
# Already fetched 921 images
# Already fetched 922 images
# Already fetched 923 images
# Already fetched 924 images
# Already fetched 925 images
# Already fetched 926 images
# Already fetched 927 images
# Already fetched 928 images
# Already fetched 929 images
# Already fetched 930 images
# Already fetched 931 images
# Already fetched 932 images
# Already fetched 933 images
# Already fetched 934 images
# Already fetched 935 images
# Already fetched 936 images
# Already fetched 937 images
# Already fetched 938 images
# Already fetched 939 images
# Already fetched 940 images
# Already fetched 941 images
# Already fetched 942 images
# Already fetched 943 images
# Already fetched 944 images
# Already fetched 945 images
# Already fetched 946 images
# Already fetched 947 images
# Already fetched 948 images
# Already fetched 949 images
# Already fetched 950 images
# Already fetched 951 images
# Already fetched 952 images
# Already fetched 953 images
# Already fetched 954 images
# Already fetched 955 images
# Already fetched 956 images
# Already fetched 957 images
# Already fetched 958 images
# Already fetched 959 images
# Already fetched 960 images
# Already fetched 961 images
# Already fetched 962 images
# Already fetched 963 images
# Already fetched 964 images
# Already fetched 965 images
# Already fetched 966 images
# Already fetched 967 images
# Already fetched 968 images
# Already fetched 969 images
# Already fetched 970 images
# Already fetched 971 images
# Already fetched 972 images
# Already fetched 973 images
# Already fetched 974 images
# Already fetched 975 images
# Already fetched 976 images
# Already fetched 977 images
# Already fetched 978 images
# Already fetched 979 images
# Already fetched 980 images
# Already fetched 981 images
# Already fetched 982 images
# Already fetched 983 images
# Already fetched 984 images
# Already fetched 985 images
# Already fetched 986 images
# Already fetched 987 images
# Already fetched 988 images
# Already fetched 989 images
# Already fetched 990 images
# Already fetched 991 images
# Already fetched 992 images
# Already fetched 993 images
# Already fetched 994 images
# Already fetched 995 images
# Already fetched 996 images
# Already fetched 997 images
# Already fetched 998 images
# Already fetched 999 images
# Already fetched 1000 images
# Already fetched 1001 images
# Already fetched 1002 images
# Already fetched 1003 images
# Already fetched 1004 images
# Already fetched 1005 images
# Already fetched 1006 images
# Already fetched 1007 images
# Already fetched 1008 images
# Already fetched 1009 images
# Already fetched 1010 images
# Already fetched 1011 images
# Already fetched 1012 images
# Already fetched 1013 images
# Already fetched 1014 images
# Already fetched 1015 images
# Already fetched 1016 images
# Already fetched 1017 images
# Already fetched 1018 images
# Already fetched 1019 images
# Already fetched 1020 images
# Already fetched 1021 images
# Already fetched 1022 images
# Already fetched 1023 images
# Already fetched 1024 images
# Already fetched 1025 images
# Already fetched 1026 images
# Already fetched 1027 images
# Already fetched 1028 images
# Already fetched 1029 images
# Already fetched 1030 images
# Already fetched 1031 images
# Already fetched 1032 images
# Already fetched 1033 images
# Already fetched 1034 images
# Already fetched 1035 images
# Already fetched 1036 images
# Already fetched 1037 images
# Already fetched 1038 images
# Already fetched 1039 images
# Already fetched 1040 images
# Already fetched 1041 images
# Already fetched 1042 images
# Already fetched 1043 images
# Already fetched 1044 images
# Already fetched 1045 images
# Already fetched 1046 images
# Already fetched 1047 images
# Already fetched 1048 images
# Already fetched 1049 images
# Already fetched 1050 images
# Already fetched 1051 images
# Already fetched 1052 images
# Already fetched 1053 images
# Already fetched 1054 images
# Already fetched 1055 images
# Already fetched 1056 images
# Already fetched 1057 images
# Already fetched 1058 images
# Already fetched 1059 images
# Already fetched 1060 images
# Already fetched 1061 images
# Already fetched 1062 images
# Already fetched 1063 images
# Already fetched 1064 images
# Already fetched 1065 images
# Already fetched 1066 images
# Already fetched 1067 images
# Already fetched 1068 images
# Already fetched 1069 images
# Already fetched 1070 images
# Already fetched 1071 images
# Already fetched 1072 images
# Already fetched 1073 images
# Already fetched 1074 images
# Already fetched 1075 images
# Already fetched 1076 images
# Already fetched 1077 images
# Already fetched 1078 images
# Already fetched 1079 images
# Already fetched 1080 images
# Already fetched 1081 images
# Already fetched 1082 images
# Already fetched 1083 images
# Already fetched 1084 images
# Already fetched 1085 images
# Already fetched 1086 images
# Already fetched 1087 images
# Already fetched 1088 images
# Already fetched 1089 images
# Already fetched 1090 images
# Already fetched 1091 images
# Already fetched 1092 images
# Already fetched 1093 images
# Already fetched 1094 images
# Already fetched 1095 images
# Already fetched 1096 images
# Already fetched 1097 images
# Already fetched 1098 images
# Already fetched 1099 images
# Already fetched 1100 images
# Already fetched 1101 images
# Already fetched 1102 images
# Already fetched 1103 images
# Already fetched 1104 images
# Already fetched 1105 images
# Already fetched 1106 images
# Already fetched 1107 images
# Already fetched 1108 images
# Already fetched 1109 images
# Already fetched 1110 images
# Already fetched 1111 images
# Already fetched 1112 images
# Already fetched 1113 images
# Already fetched 1114 images
# Already fetched 1115 images
# Already fetched 1116 images
# Already fetched 1117 images
# Already fetched 1118 images
# Already fetched 1119 images
# Already fetched 1120 images
# Already fetched 1121 images
# Already fetched 1122 images
# Already fetched 1123 images
# Already fetched 1124 images
# Already fetched 1125 images
# Already fetched 1126 images
# Already fetched 1127 images
# Already fetched 1128 images
# Already fetched 1129 images
# Already fetched 1130 images
# Already fetched 1131 images
# Already fetched 1132 images
# Already fetched 1133 images
# Already fetched 1134 images
# Already fetched 1135 images
# Already fetched 1136 images
# Already fetched 1137 images
# Already fetched 1138 images
# Already fetched 1139 images
# Already fetched 1140 images
# Already fetched 1141 images
# Already fetched 1142 images
# Already fetched 1143 images
# Already fetched 1144 images
# Already fetched 1145 images
# Already fetched 1146 images
# Already fetched 1147 images
# Already fetched 1148 images
# Already fetched 1149 images
# Already fetched 1150 images
# Already fetched 1151 images
# Already fetched 1152 images
# Already fetched 1153 images
# Already fetched 1154 images
# Already fetched 1155 images
# Already fetched 1156 images
# Already fetched 1157 images
# Already fetched 1158 images
# Already fetched 1159 images
# Already fetched 1160 images
# Already fetched 1161 images
# Already fetched 1162 images
# Already fetched 1163 images
# Already fetched 1164 images
# Already fetched 1165 images
# Already fetched 1166 images
# Already fetched 1167 images
# Already fetched 1168 images
# Already fetched 1169 images
# Already fetched 1170 images
# Already fetched 1171 images
# Already fetched 1172 images
# Already fetched 1173 images
# Already fetched 1174 images
# Already fetched 1175 images
# Already fetched 1176 images
# Already fetched 1177 images
# Already fetched 1178 images
# Already fetched 1179 images
# Already fetched 1180 images
# Already fetched 1181 images
# Already fetched 1182 images
# Already fetched 1183 images
# Already fetched 1184 images
# Already fetched 1185 images
# Already fetched 1186 images
# Already fetched 1187 images
# Already fetched 1188 images
# Already fetched 1189 images
# Already fetched 1190 images
# Already fetched 1191 images
# Already fetched 1192 images
# Already fetched 1193 images
# Already fetched 1194 images
# Already fetched 1195 images
# Already fetched 1196 images
# Already fetched 1197 images
# Already fetched 1198 images
# Already fetched 1199 images
# Already fetched 1200 images
# Already fetched 1201 images
# Already fetched 1202 images
# Already fetched 1203 images
# Already fetched 1204 images
# Already fetched 1205 images
# Already fetched 1206 images
# Already fetched 1207 images
# Already fetched 1208 images
# Already fetched 1209 images
# Already fetched 1210 images
# Already fetched 1211 images
# Already fetched 1212 images
# Already fetched 1213 images
# Already fetched 1214 images
# Already fetched 1215 images
# Already fetched 1216 images
# Already fetched 1217 images
# Already fetched 1218 images
# Already fetched 1219 images
# Already fetched 1220 images
# Already fetched 1221 images
# Already fetched 1222 images
# Already fetched 1223 images
# Already fetched 1224 images
# Already fetched 1225 images
# Already fetched 1226 images
# Already fetched 1227 images
# Already fetched 1228 images
# Already fetched 1229 images
# Already fetched 1230 images
# Already fetched 1231 images
# Already fetched 1232 images
# Already fetched 1233 images
# Already fetched 1234 images
# Already fetched 1235 images
# Already fetched 1236 images
# Already fetched 1237 images
# Already fetched 1238 images
# Already fetched 1239 images
# Already fetched 1240 images
# Already fetched 1241 images
# Already fetched 1242 images
# Already fetched 1243 images
# Already fetched 1244 images
# Already fetched 1245 images
# Already fetched 1246 images
# Already fetched 1247 images
# Already fetched 1248 images
# Already fetched 1249 images
# Already fetched 1250 images
# Already fetched 1251 images
# Already fetched 1252 images
# Already fetched 1253 images
# Already fetched 1254 images
# Already fetched 1255 images
# Already fetched 1256 images
# Already fetched 1257 images
# Already fetched 1258 images
# Already fetched 1259 images
# Already fetched 1260 images
# Already fetched 1261 images
# Already fetched 1262 images
# Already fetched 1263 images
# Already fetched 1264 images
# Already fetched 1265 images
# Already fetched 1266 images
# Already fetched 1267 images
# Already fetched 1268 images
# Already fetched 1269 images
# Already fetched 1270 images
# Already fetched 1271 images
# Already fetched 1272 images
# Already fetched 1273 images
# Already fetched 1274 images
# Already fetched 1275 images
# Already fetched 1276 images
# Already fetched 1277 images
# Already fetched 1278 images
# Already fetched 1279 images
# Already fetched 1280 images
# Already fetched 1281 images
# Already fetched 1282 images
# Already fetched 1283 images
# Already fetched 1284 images
# Already fetched 1285 images
# Already fetched 1286 images
# Already fetched 1287 images
# Already fetched 1288 images
# Already fetched 1289 images
# Already fetched 1290 images
# Already fetched 1291 images
# Already fetched 1292 images
# Already fetched 1293 images
# Already fetched 1294 images
# Already fetched 1295 images
# Already fetched 1296 images
# Already fetched 1297 images
# Already fetched 1298 images
# Already fetched 1299 images
# Already fetched 1300 images
# Already fetched 1301 images
# Already fetched 1302 images
# Already fetched 1303 images
# Already fetched 1304 images
# Already fetched 1305 images
# Already fetched 1306 images
# Already fetched 1307 images
# Already fetched 1308 images
# Already fetched 1309 images
# Already fetched 1310 images
# Already fetched 1311 images
# Already fetched 1312 images
# Already fetched 1313 images
# Already fetched 1314 images
# Already fetched 1315 images
# Already fetched 1316 images
# Already fetched 1317 images
# Already fetched 1318 images
# Already fetched 1319 images
# Already fetched 1320 images
# Already fetched 1321 images
# Already fetched 1322 images
# Already fetched 1323 images
# Already fetched 1324 images
# Already fetched 1325 images
# Already fetched 1326 images
# Already fetched 1327 images
# Already fetched 1328 images
# Already fetched 1329 images
# Already fetched 1330 images
# Already fetched 1331 images
# Already fetched 1332 images
# Already fetched 1333 images
# Already fetched 1334 images
# Already fetched 1335 images
# Already fetched 1336 images
# Already fetched 1337 images
# Already fetched 1338 images
# Already fetched 1339 images
# Already fetched 1340 images
# Already fetched 1341 images
# Already fetched 1342 images
# Already fetched 1343 images
# Already fetched 1344 images
# Already fetched 1345 images
# Already fetched 1346 images
# Already fetched 1347 images
# Already fetched 1348 images
# Already fetched 1349 images
# Already fetched 1350 images
# Already fetched 1351 images
# Already fetched 1352 images
# Already fetched 1353 images
# Already fetched 1354 images
# Already fetched 1355 images
# Already fetched 1356 images
# Already fetched 1357 images
# Already fetched 1358 images
# Already fetched 1359 images
# Already fetched 1360 images
# Already fetched 1361 images
# Already fetched 1362 images
# Already fetched 1363 images
# Already fetched 1364 images
# Already fetched 1365 images
# Already fetched 1366 images
# Already fetched 1367 images
# Already fetched 1368 images
# Already fetched 1369 images
# Already fetched 1370 images
# Already fetched 1371 images
# Already fetched 1372 images
# Already fetched 1373 images
# Already fetched 1374 images
# Already fetched 1375 images
# Already fetched 1376 images
# Already fetched 1377 images
# Already fetched 1378 images
# Already fetched 1379 images
# Already fetched 1380 images
# Already fetched 1381 images
# Already fetched 1382 images
# Already fetched 1383 images
# Already fetched 1384 images
# Already fetched 1385 images
# Already fetched 1386 images
# Already fetched 1387 images
# Already fetched 1388 images
# Already fetched 1389 images
# Already fetched 1390 images
# Already fetched 1391 images
# Already fetched 1392 images
# Already fetched 1393 images
# Already fetched 1394 images
# Already fetched 1395 images
# Already fetched 1396 images
# Already fetched 1397 images
# Already fetched 1398 images
# Already fetched 1399 images
# Already fetched 1400 images
# Already fetched 1401 images
# Already fetched 1402 images
# Already fetched 1403 images
# Already fetched 1404 images
# Already fetched 1405 images
# Already fetched 1406 images
# Already fetched 1407 images
# Already fetched 1408 images
# Already fetched 1409 images
# Already fetched 1410 images
# Already fetched 1411 images
# Already fetched 1412 images
# Already fetched 1413 images
# Already fetched 1414 images
# Already fetched 1415 images
# Already fetched 1416 images
# Already fetched 1417 images
# Already fetched 1418 images
# Already fetched 1419 images
# Already fetched 1420 images
# Already fetched 1421 images
# Already fetched 1422 images
# Already fetched 1423 images
# Already fetched 1424 images
# Already fetched 1425 images
# Already fetched 1426 images
# Already fetched 1427 images
# Already fetched 1428 images
# Already fetched 1429 images
# Already fetched 1430 images
# Already fetched 1431 images
# Already fetched 1432 images
# Already fetched 1433 images
# Already fetched 1434 images
# Already fetched 1435 images
# Already fetched 1436 images
# Already fetched 1437 images
# Already fetched 1438 images
# Already fetched 1439 images
# Already fetched 1440 images
# Already fetched 1441 images
# Already fetched 1442 images
# Already fetched 1443 images
# Already fetched 1444 images
# Already fetched 1445 images
# Already fetched 1446 images
# Already fetched 1447 images
# Already fetched 1448 images
# Already fetched 1449 images
# Already fetched 1450 images
# Already fetched 1451 images
# Already fetched 1452 images
# Already fetched 1453 images
# Already fetched 1454 images
# Already fetched 1455 images
# Already fetched 1456 images
# Already fetched 1457 images
# Already fetched 1458 images
# Already fetched 1459 images
# Already fetched 1460 images
# Already fetched 1461 images
# Already fetched 1462 images
# Already fetched 1463 images
# Already fetched 1464 images
# Already fetched 1465 images
# Already fetched 1466 images
# Already fetched 1467 images
# Already fetched 1468 images
# Already fetched 1469 images
# Already fetched 1470 images
# Already fetched 1471 images
# Already fetched 1472 images
# Already fetched 1473 images
# Already fetched 1474 images
# Already fetched 1475 images
# Already fetched 1476 images
# Already fetched 1477 images
# Already fetched 1478 images
# Already fetched 1479 images
# Already fetched 1480 images
# Already fetched 1481 images
# Already fetched 1482 images
# Already fetched 1483 images
# Already fetched 1484 images
# Already fetched 1485 images
# Already fetched 1486 images
# Already fetched 1487 images
# Already fetched 1488 images
# Already fetched 1489 images
# Already fetched 1490 images
# Already fetched 1491 images
# Already fetched 1492 images
# Already fetched 1493 images
# Already fetched 1494 images
# Already fetched 1495 images
# Already fetched 1496 images
# Already fetched 1497 images
# Already fetched 1498 images
# Already fetched 1499 images
# Already fetched 1500 images
# Already fetched 1501 images
# Already fetched 1502 images
# Already fetched 1503 images
# Already fetched 1504 images
# Already fetched 1505 images
# Already fetched 1506 images
# Already fetched 1507 images
# Already fetched 1508 images
# Already fetched 1509 images
# Already fetched 1510 images
# Already fetched 1511 images
# Already fetched 1512 images
# Already fetched 1513 images
# Already fetched 1514 images
# Already fetched 1515 images
# Already fetched 1516 images
# Already fetched 1517 images
# Already fetched 1518 images
# Already fetched 1519 images
# Already fetched 1520 images
# Already fetched 1521 images
# Already fetched 1522 images
# Already fetched 1523 images
# Already fetched 1524 images
# Already fetched 1525 images
# Already fetched 1526 images
# Already fetched 1527 images
# Already fetched 1528 images
# Already fetched 1529 images
# Already fetched 1530 images
# Already fetched 1531 images
# Already fetched 1532 images
# Already fetched 1533 images
# Already fetched 1534 images
# Already fetched 1535 images
# Already fetched 1536 images
# Already fetched 1537 images
# Already fetched 1538 images
# Already fetched 1539 images
# Already fetched 1540 images
# Already fetched 1541 images
# Already fetched 1542 images
# Already fetched 1543 images
# Already fetched 1544 images
# Already fetched 1545 images
# Already fetched 1546 images
# Already fetched 1547 images
# Already fetched 1548 images
# Already fetched 1549 images
# Already fetched 1550 images
# Already fetched 1551 images
# Already fetched 1552 images
# Already fetched 1553 images
# Already fetched 1554 images
# Already fetched 1555 images
# Already fetched 1556 images
# Already fetched 1557 images
# Already fetched 1558 images
# Already fetched 1559 images
# Already fetched 1560 images
# Already fetched 1561 images
# Already fetched 1562 images
# Already fetched 1563 images
# Already fetched 1564 images
# Already fetched 1565 images
# Already fetched 1566 images
# Already fetched 1567 images
# Already fetched 1568 images
# Already fetched 1569 images
# Already fetched 1570 images
# Already fetched 1571 images
# Already fetched 1572 images
# Already fetched 1573 images
# Already fetched 1574 images
# Already fetched 1575 images
# Already fetched 1576 images
# Already fetched 1577 images
# Already fetched 1578 images
# Already fetched 1579 images
# Already fetched 1580 images
# Already fetched 1581 images
# Already fetched 1582 images
# Already fetched 1583 images
# Already fetched 1584 images
# Already fetched 1585 images
# Already fetched 1586 images
# Already fetched 1587 images
# Already fetched 1588 images
# Already fetched 1589 images
# Already fetched 1590 images
# Already fetched 1591 images
# Already fetched 1592 images
# Already fetched 1593 images
# Already fetched 1594 images
# Already fetched 1595 images
# Already fetched 1596 images
# Already fetched 1597 images
# Already fetched 1598 images
# Already fetched 1599 images
# Already fetched 1600 images
# Already fetched 1601 images
# Already fetched 1602 images
# Already fetched 1603 images
# Already fetched 1604 images
# Already fetched 1605 images
# Already fetched 1606 images
# Already fetched 1607 images
# Already fetched 1608 images
# Already fetched 1609 images
# Already fetched 1610 images
# Already fetched 1611 images
# Already fetched 1612 images
# Already fetched 1613 images
# Already fetched 1614 images
# Already fetched 1615 images
# Already fetched 1616 images
# Already fetched 1617 images
# Already fetched 1618 images
# Already fetched 1619 images
# Already fetched 1620 images
# Already fetched 1621 images
# Already fetched 1622 images
# Already fetched 1623 images
# Already fetched 1624 images
# Already fetched 1625 images
# Already fetched 1626 images
# Already fetched 1627 images
# Already fetched 1628 images
# Already fetched 1629 images
# Already fetched 1630 images
# Already fetched 1631 images
# Already fetched 1632 images
# Already fetched 1633 images
# Already fetched 1634 images
# Already fetched 1635 images
# Already fetched 1636 images
# Already fetched 1637 images
# Already fetched 1638 images
# Already fetched 1639 images
# Already fetched 1640 images
# Already fetched 1641 images
# Already fetched 1642 images
# Already fetched 1643 images
# Already fetched 1644 images
# Already fetched 1645 images
# Already fetched 1646 images
# Already fetched 1647 images
# Already fetched 1648 images
# Already fetched 1649 images
# Already fetched 1650 images
# Already fetched 1651 images
# Already fetched 1652 images
# Already fetched 1653 images
# Already fetched 1654 images
# Already fetched 1655 images
# Already fetched 1656 images
# Already fetched 1657 images
# Already fetched 1658 images
# Already fetched 1659 images
# Already fetched 1660 images
# Already fetched 1661 images
# Already fetched 1662 images
# Already fetched 1663 images
# Already fetched 1664 images
# Already fetched 1665 images
# Already fetched 1666 images
# Already fetched 1667 images
# Already fetched 1668 images
# Already fetched 1669 images
# Already fetched 1670 images
# Already fetched 1671 images
# Already fetched 1672 images
# Already fetched 1673 images
# Already fetched 1674 images
# Already fetched 1675 images
# Already fetched 1676 images
# Already fetched 1677 images
# Already fetched 1678 images
# Already fetched 1679 images
# Already fetched 1680 images
# Already fetched 1681 images
# Already fetched 1682 images
# Already fetched 1683 images
# Already fetched 1684 images
# Already fetched 1685 images
# Already fetched 1686 images
# Already fetched 1687 images
# Already fetched 1688 images
# Already fetched 1689 images
# Already fetched 1690 images
# Already fetched 1691 images
# Already fetched 1692 images
# Already fetched 1693 images
# Already fetched 1694 images
# Already fetched 1695 images
# Already fetched 1696 images
# Already fetched 1697 images
# Already fetched 1698 images
# Already fetched 1699 images
# Already fetched 1700 images
# Already fetched 1701 images
# Already fetched 1702 images
# Already fetched 1703 images
# Already fetched 1704 images
# Already fetched 1705 images
# Already fetched 1706 images
# Already fetched 1707 images
# Already fetched 1708 images
# Already fetched 1709 images
# Already fetched 1710 images
# Already fetched 1711 images
# Already fetched 1712 images
# Already fetched 1713 images
# Already fetched 1714 images
# Already fetched 1715 images
# Already fetched 1716 images
# Already fetched 1717 images
# Already fetched 1718 images
# Already fetched 1719 images
# Already fetched 1720 images
# Already fetched 1721 images
# Already fetched 1722 images
# Already fetched 1723 images
# Already fetched 1724 images
# Already fetched 1725 images
# Already fetched 1726 images
# Already fetched 1727 images
# Already fetched 1728 images
# Already fetched 1729 images
# Already fetched 1730 images
# Already fetched 1731 images
# Already fetched 1732 images
# Already fetched 1733 images
# Already fetched 1734 images
# Already fetched 1735 images
# Already fetched 1736 images
# Already fetched 1737 images
# Already fetched 1738 images
# Already fetched 1739 images
# Already fetched 1740 images
# Already fetched 1741 images
# Already fetched 1742 images
# Already fetched 1743 images
# Already fetched 1744 images
# Already fetched 1745 images
# Already fetched 1746 images
# Already fetched 1747 images
# Already fetched 1748 images
# Already fetched 1749 images
# Already fetched 1750 images
# Already fetched 1751 images
# Already fetched 1752 images
# ...
# Already fetched 17503 images
# Already fetched 17504 images
# Already fetched 17505 images
# Already fetched 17506 images
# Already fetched 17507 images
# Already fetched 17508 images
# Already fetched 17509 images
# Already fetched 17510 images
# Already fetched 17511 images
# Already fetched 17512 images
# Already fetched 17513 images
# Already fetched 17514 images
# Already fetched 17515 images
# Already fetched 17516 images
# Already fetched 17517 images
# Already fetched 17518 images
# Already fetched 17519 images
# Already fetched 17520 images
# Already fetched 17521 images
# Already fetched 17522 images
# Already fetched 17523 images
# Already fetched 17524 images
# Already fetched 17525 images
# Already fetched 17526 images
# Already fetched 17527 images
# Already fetched 17528 images
# Already fetched 17529 images
# Already fetched 17530 images
# Already fetched 17531 images
# Already fetched 17532 images
# Already fetched 17533 images
# Already fetched 17534 images
# Already fetched 17535 images
# Already fetched 17536 images
# Already fetched 17537 images
# Already fetched 17538 images
# Already fetched 17539 images
# Already fetched 17540 images
# Already fetched 17541 images
# Already fetched 17542 images
# Already fetched 17543 images
# Already fetched 17544 images
# Already fetched 17545 images
# Already fetched 17546 images
# Already fetched 17547 images
# Already fetched 17548 images
# Already fetched 17549 images
# Already fetched 17550 images
# Already fetched 17551 images
# Already fetched 17552 images
# Already fetched 17553 images
# Already fetched 17554 images
# Already fetched 17555 images
# Already fetched 17556 images
# Already fetched 17557 images
# Already fetched 17558 images
# Already fetched 17559 images
# Already fetched 17560 images
# Already fetched 17561 images
# Already fetched 17562 images
# Already fetched 17563 images
# Already fetched 17564 images
# Already fetched 17565 images
# Already fetched 17566 images
# Already fetched 17567 images
# Already fetched 17568 images
# Already fetched 17569 images
# Already fetched 17570 images
# Already fetched 17571 images
# Already fetched 17572 images
# Already fetched 17573 images
# Already fetched 17574 images
# Already fetched 17575 images
# Already fetched 17576 images
# Already fetched 17577 images
# Already fetched 17578 images
# Already fetched 17579 images
# Already fetched 17580 images
# Already fetched 17581 images
# Already fetched 17582 images
# Already fetched 17583 images
# Already fetched 17584 images
# Already fetched 17585 images
# Already fetched 17586 images
# Already fetched 17587 images
# Already fetched 17588 images
# Already fetched 17589 images
# Already fetched 17590 images
# Already fetched 17591 images
# Already fetched 17592 images
# Already fetched 17593 images
# Already fetched 17594 images
# Already fetched 17595 images
# Already fetched 17596 images
# Already fetched 17597 images
# Already fetched 17598 images
# Already fetched 17599 images
# Already fetched 17600 images
# Already fetched 17601 images
# Already fetched 17602 images
# Already fetched 17603 images
# Already fetched 17604 images
# Already fetched 17605 images
# Already fetched 17606 images
# Already fetched 17607 images
# Already fetched 17608 images
# Already fetched 17609 images
# Already fetched 17610 images
# Already fetched 17611 images
# Already fetched 17612 images
# Already fetched 17613 images
# Already fetched 17614 images
# Already fetched 17615 images
# Already fetched 17616 images
# Already fetched 17617 images
# Already fetched 17618 images
# Already fetched 17619 images
# Already fetched 17620 images
# Already fetched 17621 images
# Already fetched 17622 images
# Already fetched 17623 images
# Already fetched 17624 images
# Already fetched 17625 images
# Already fetched 17626 images
# Already fetched 17627 images
# Already fetched 17628 images
# Already fetched 17629 images
# Already fetched 17630 images
# Already fetched 17631 images
# Already fetched 17632 images
# Already fetched 17633 images
# Already fetched 17634 images
# Already fetched 17635 images
# Already fetched 17636 images
# Already fetched 17637 images
# Already fetched 17638 images
# Already fetched 17639 images
# Already fetched 17640 images
# Already fetched 17641 images
# Already fetched 17642 images
# Already fetched 17643 images
# Already fetched 17644 images
# Already fetched 17645 images
# Already fetched 17646 images
# Already fetched 17647 images
# Already fetched 17648 images
# Already fetched 17649 images
# Already fetched 17650 images
# Already fetched 17651 images
# Already fetched 17652 images
# Already fetched 17653 images
# Already fetched 17654 images
# Already fetched 17655 images
# Already fetched 17656 images
# Already fetched 17657 images
# Already fetched 17658 images
# Already fetched 17659 images
# Already fetched 17660 images
# Already fetched 17661 images
# Already fetched 17662 images
# Already fetched 17663 images
# Already fetched 17664 images
# Already fetched 17665 images
# Already fetched 17666 images
# Already fetched 17667 images
# Already fetched 17668 images
# Already fetched 17669 images
# Already fetched 17670 images
# Already fetched 17671 images
# Already fetched 17672 images
# Already fetched 17673 images
# Already fetched 17674 images
# Already fetched 17675 images
# Already fetched 17676 images
# Already fetched 17677 images
# Already fetched 17678 images
# Already fetched 17679 images
# Already fetched 17680 images
# Already fetched 17681 images
# Already fetched 17682 images
# Already fetched 17683 images
# Already fetched 17684 images
# Already fetched 17685 images
# Already fetched 17686 images
# Already fetched 17687 images
# Already fetched 17688 images
# Already fetched 17689 images
# Already fetched 17690 images
# Already fetched 17691 images
# Already fetched 17692 images
# Already fetched 17693 images
# Already fetched 17694 images
# Already fetched 17695 images
# Already fetched 17696 images
# Already fetched 17697 images
# Already fetched 17698 images
# Already fetched 17699 images
# Already fetched 17700 images
# Already fetched 17701 images
# Already fetched 17702 images
# Already fetched 17703 images
# Already fetched 17704 images
# Already fetched 17705 images
# Already fetched 17706 images
# Already fetched 17707 images
# Already fetched 17708 images
# Already fetched 17709 images
# Already fetched 17710 images
# Already fetched 17711 images
# Already fetched 17712 images
# Already fetched 17713 images
# Already fetched 17714 images
# Already fetched 17715 images
# Already fetched 17716 images
# Already fetched 17717 images
# Already fetched 17718 images
# Already fetched 17719 images
# Already fetched 17720 images
# Already fetched 17721 images
# Already fetched 17722 images
# Already fetched 17723 images
# Already fetched 17724 images
# Already fetched 17725 images
# Already fetched 17726 images
# Already fetched 17727 images
# Already fetched 17728 images
# Already fetched 17729 images
# Already fetched 17730 images
# Already fetched 17731 images
# Already fetched 17732 images
# Already fetched 17733 images
# Already fetched 17734 images
# Already fetched 17735 images
# Already fetched 17736 images
# Already fetched 17737 images
# Already fetched 17738 images
# Already fetched 17739 images
# Already fetched 17740 images
# Already fetched 17741 images
# Already fetched 17742 images
# Already fetched 17743 images
# Already fetched 17744 images
# Already fetched 17745 images
# Already fetched 17746 images
# Already fetched 17747 images
# Already fetched 17748 images
# Already fetched 17749 images
# Already fetched 17750 images
# Already fetched 17751 images
# Already fetched 17752 images
# Already fetched 17753 images
# Already fetched 17754 images
# Already fetched 17755 images
# Already fetched 17756 images
# Already fetched 17757 images
# Already fetched 17758 images
# Already fetched 17759 images
# Already fetched 17760 images
# Already fetched 17761 images
# Already fetched 17762 images
# Already fetched 17763 images
# Already fetched 17764 images
# Already fetched 17765 images
# Already fetched 17766 images
# Already fetched 17767 images
# Already fetched 17768 images
# Already fetched 17769 images
# Already fetched 17770 images
# Already fetched 17771 images
# Already fetched 17772 images
# Already fetched 17773 images
# Already fetched 17774 images
# Already fetched 17775 images
# Already fetched 17776 images
# Already fetched 17777 images
# Already fetched 17778 images
# Already fetched 17779 images
# Already fetched 17780 images
# Already fetched 17781 images
# Already fetched 17782 images
# Already fetched 17783 images
# Already fetched 17784 images
# Already fetched 17785 images
# Already fetched 17786 images
# Already fetched 17787 images
# Already fetched 17788 images
# Already fetched 17789 images
# Already fetched 17790 images
# Already fetched 17791 images
# Already fetched 17792 images
# Already fetched 17793 images
# Already fetched 17794 images
# Already fetched 17795 images
# Already fetched 17796 images
# Already fetched 17797 images
# Already fetched 17798 images
# Already fetched 17799 images
# Already fetched 17800 images
# Already fetched 17801 images
# Already fetched 17802 images
# Already fetched 17803 images
# Already fetched 17804 images
# Already fetched 17805 images
# Already fetched 17806 images
# Already fetched 17807 images
# Already fetched 17808 images
# Already fetched 17809 images
# Already fetched 17810 images
# Already fetched 17811 images
# Already fetched 17812 images
# Already fetched 17813 images
# Already fetched 17814 images
# Already fetched 17815 images
# Already fetched 17816 images
# Already fetched 17817 images
# Already fetched 17818 images
# Already fetched 17819 images
# Already fetched 17820 images
# Already fetched 17821 images
# Already fetched 17822 images
# Already fetched 17823 images
# Already fetched 17824 images
# Already fetched 17825 images
# Already fetched 17826 images
# Already fetched 17827 images
# Already fetched 17828 images
# Already fetched 17829 images
# Already fetched 17830 images
# Already fetched 17831 images
# Already fetched 17832 images
# Already fetched 17833 images
# Already fetched 17834 images
# Already fetched 17835 images
# Already fetched 17836 images
# Already fetched 17837 images
# Already fetched 17838 images
# Already fetched 17839 images
# Already fetched 17840 images
# Already fetched 17841 images
# Already fetched 17842 images
# Already fetched 17843 images
# Already fetched 17844 images
# Already fetched 17845 images
# Already fetched 17846 images
# Already fetched 17847 images
# Already fetched 17848 images
# Already fetched 17849 images
# Already fetched 17850 images
# Already fetched 17851 images
# Already fetched 17852 images
# Already fetched 17853 images
# Already fetched 17854 images
# Already fetched 17855 images
# Already fetched 17856 images
# Already fetched 17857 images
# Already fetched 17858 images
# Already fetched 17859 images
# Already fetched 17860 images
# Already fetched 17861 images
# Already fetched 17862 images
# Already fetched 17863 images
# Already fetched 17864 images
# Already fetched 17865 images
# Already fetched 17866 images
# Already fetched 17867 images
# Already fetched 17868 images
# Already fetched 17869 images
# Already fetched 17870 images
# Already fetched 17871 images
# Already fetched 17872 images
# Already fetched 17873 images
# Already fetched 17874 images
# Already fetched 17875 images
# Already fetched 17876 images
# Already fetched 17877 images
# Already fetched 17878 images
# Already fetched 17879 images
# Already fetched 17880 images
# Already fetched 17881 images
# Already fetched 17882 images
# Already fetched 17883 images
# Already fetched 17884 images
# Already fetched 17885 images
# Already fetched 17886 images
# Already fetched 17887 images
# Already fetched 17888 images
# Already fetched 17889 images
# Already fetched 17890 images
# Already fetched 17891 images
# Already fetched 17892 images
# Already fetched 17893 images
# Already fetched 17894 images
# Already fetched 17895 images
# Already fetched 17896 images
# Already fetched 17897 images
# Already fetched 17898 images
# Already fetched 17899 images
# Already fetched 17900 images
# Already fetched 17901 images
# Already fetched 17902 images
# Already fetched 17903 images
# Already fetched 17904 images
# Already fetched 17905 images
# Already fetched 17906 images
# Already fetched 17907 images
# Already fetched 17908 images
# Already fetched 17909 images
# Already fetched 17910 images
# Already fetched 17911 images
# Already fetched 17912 images
# Already fetched 17913 images
# Already fetched 17914 images
# Already fetched 17915 images
# Already fetched 17916 images
# Already fetched 17917 images
# Already fetched 17918 images
# Already fetched 17919 images
# Already fetched 17920 images
# Already fetched 17921 images
# Already fetched 17922 images
# Already fetched 17923 images
# Already fetched 17924 images
# Already fetched 17925 images
# Already fetched 17926 images
# Already fetched 17927 images
# Already fetched 17928 images
# Already fetched 17929 images
# Already fetched 17930 images
# Already fetched 17931 images
# Already fetched 17932 images
# Already fetched 17933 images
# Already fetched 17934 images
# Already fetched 17935 images
# Already fetched 17936 images
# Already fetched 17937 images
# Already fetched 17938 images
# Already fetched 17939 images
# Already fetched 17940 images
# Already fetched 17941 images
# Already fetched 17942 images
# Already fetched 17943 images
# Already fetched 17944 images
# Already fetched 17945 images
# Already fetched 17946 images
# Already fetched 17947 images
# Already fetched 17948 images
# Already fetched 17949 images
# Already fetched 17950 images
# Already fetched 17951 images
# Already fetched 17952 images
# Already fetched 17953 images
# Already fetched 17954 images
# Already fetched 17955 images
# Already fetched 17956 images
# Already fetched 17957 images
# Already fetched 17958 images
# Already fetched 17959 images
# Already fetched 17960 images
# Already fetched 17961 images
# Already fetched 17962 images
# Already fetched 17963 images
# Already fetched 17964 images
# Already fetched 17965 images
# Already fetched 17966 images
# Already fetched 17967 images
# Already fetched 17968 images
# Already fetched 17969 images
# Already fetched 17970 images
# Already fetched 17971 images
# Already fetched 17972 images
# Already fetched 17973 images
# Already fetched 17974 images
# Already fetched 17975 images
# Already fetched 17976 images
# Already fetched 17977 images
# Already fetched 17978 images
# Already fetched 17979 images
# Already fetched 17980 images
# Already fetched 17981 images
# Already fetched 17982 images
# Already fetched 17983 images
# Already fetched 17984 images
# Already fetched 17985 images
# Already fetched 17986 images
# Already fetched 17987 images
# Already fetched 17988 images
# Already fetched 17989 images
# Already fetched 17990 images
# Already fetched 17991 images
# Already fetched 17992 images
# Already fetched 17993 images
# Already fetched 17994 images
# Already fetched 17995 images
# Already fetched 17996 images
# Already fetched 17997 images
# Already fetched 17998 images
# Already fetched 17999 images
# Already fetched 18000 images
# Already fetched 18001 images
# Already fetched 18002 images
# Already fetched 18003 images
# Already fetched 18004 images
# Already fetched 18005 images
# Already fetched 18006 images
# Already fetched 18007 images
# Already fetched 18008 images
# Already fetched 18009 images
# Already fetched 18010 images
# Already fetched 18011 images
# Already fetched 18012 images
# Already fetched 18013 images
# Already fetched 18014 images
# Already fetched 18015 images
# Already fetched 18016 images
# Already fetched 18017 images
# Already fetched 18018 images
# Already fetched 18019 images
# Already fetched 18020 images
# Already fetched 18021 images
# Already fetched 18022 images
# Already fetched 18023 images
# Already fetched 18024 images
# Already fetched 18025 images
# Already fetched 18026 images
# Already fetched 18027 images
# Already fetched 18028 images
# Already fetched 18029 images
# Already fetched 18030 images
# Already fetched 18031 images
# Already fetched 18032 images
# Already fetched 18033 images
# Already fetched 18034 images
# Already fetched 18035 images
# Already fetched 18036 images
# Already fetched 18037 images
# Already fetched 18038 images
# Already fetched 18039 images
# Already fetched 18040 images
# Already fetched 18041 images
# Already fetched 18042 images
# Already fetched 18043 images
# Already fetched 18044 images
# Already fetched 18045 images
# Already fetched 18046 images
# Already fetched 18047 images
# Already fetched 18048 images
# Already fetched 18049 images
# Already fetched 18050 images
# Already fetched 18051 images
# Already fetched 18052 images
# 18052 images found on local disk.

# %% [markdown]
# # 2. Select the data of interest for our study.

# %% [markdown]
# Each class is a condition. The data samples are contrast maps showing the effect of a condition on brain activity with respect to a baseline activity. In this section, we:
# - retrieve all classes from the collection of NeuroVault,
# - look at the number of data samples per class.

# %%
# The collection of Neurovault contains many contrast maps (data samples).
# Some of them show the effect of a condition over a baseline 
# (elementary contrast maps). Others represent more complex relationships such as 
# the effect of a condition over another condition.
# Not to include unwanted bias, we only kept the elementary contrast maps in the benchmark.
# In NeuroVault, their names look like "condition vs baseline" or only "condition".

# Additionally, we removed the two classes studied in the 'bang' task,
# as only 11 data samples are available per class.

# Create a list containing the name of all classes.
classes = set()

# We go through all contrast maps from the NeuroVault collection.
for image in data.images_meta:
    # We retrieve the name of the contrast.
    contrast_definition = image['contrast_definition']
    classes.add(image['contrast_definition'])                
classes = list(classes)

# %%
df_4337 = pd.DataFrame(columns=['task','name','contrast_definition'])
for image in data.images_meta:
    df_4337 = df_4337.append({'task':image['task'],'name':image['name'],
                              'contrast_definition':image['contrast_definition']},ignore_index=True)
df_4337['subject_id']=df_4337.name.apply(lambda x :x.split('_')[0])

# %%
df_4337[df_4337.contrast_definition.isin(classes)].groupby(['task','contrast_definition']).agg({'subject_id':'nunique'}).rename(columns={'subject_id':'number_of_subject'})
# Out:
#                                 number_of_subject
# task       contrast_definition
# EMOTION    FACES                              786
#            SHAPES                             786
# GAMBLING   PUNISH                             785
#            REWARD                             787
# LANGUAGE   MATH                               786
#            STORY                              786
# MOTOR      CUE                                786
#            LF                                 783
#            LH                                 786
#            RF                                 785
#            RH                                 786
# RELATIONAL MATCH                              785
#            REL                                785
# SOCIAL     RANDOM                             785
#            TOM                                783
# WM         0BK_BODY                           785
#            0BK_FACE                           785
#            0BK_PLACE                          785
#            0BK_TOOL                           781
#            2BK_BODY                           785
#            2BK_FACE                           783
#            2BK_PLACE                          784
#            2BK_TOOL                           784

# %% [markdown]
# In the IBC dataset, data were collected with at least two acquisitions with opposite phase-encoding directions (AP or PA) per task and per subject. Statistics of their joint effects were calculated under a Fixed-Effects (FFX) model. As in machine learning the more samples we use the more performant the model will be, we chose to use the contrasts generated from the AP or PA instead of the ones calculated from a FFX model.

# %%
# Number of data samples per class.
examples = {}
[examples.setdefault(c, 0) for c in classes]

# We go through all contrast maps from the NeuroVault collection.
for image in data.images_meta:
    # We retrieve the name of the contrast.
    contrast_definition = image['contrast_definition']
    # We only keep the AP / PA contrasts.
    if contrast_definition in classes:
        name = image['name'].split('_')
        if 'ffx' not in name:
            examples[contrast_definition] += 1

print('min:', min(examples.values()), '\nQ1:', np.percentile(list(examples.values()), 25, interpolation = 'midpoint'), '\nmedian:', np.median(list(examples.values())), '\nQ3:', np.percentile(list(examples.values()), 75, interpolation = 'midpoint') , '\nmax:', max(examples.values()))
print("The total number of data samples in our study is", np.sum(list(examples.values())), '.')
# Out:
# min: 781
# Q1: 784.5
# median: 785.0
# Q3: 786.0
# max: 787
# The total number of data samples in our study is 18052 .

# %%
# Number of examples per class and per task.
# Retrieve the names of the tasks.
tasks = []
for image in data.images_meta:
    if image['task'] not in tasks:
        tasks.append(image['task'])

# Retrieve to which task a condition is associated with.
contrasts = {}
[contrasts.setdefault(task, []) for task in tasks]

for image in data.images_meta:
    if image['contrast_definition'] not in contrasts[image['task']]:
        contrasts[image['task']].append(image['contrast_definition'])

# Per task, retrieve the conditions and the number of examples for each condition.
examples_per_task = {}
[examples_per_task.setdefault(task, []) for task in tasks]
actual_tasks = []
for condition in examples.keys():
    # Retrieve the task associated to the condition
    for key in contrasts.keys():
        if condition in contrasts[key]:
            task = key
            if task not in actual_tasks:
                actual_tasks.append(task)
            break
    examples_per_task[task].append({condition: examples[condition]})

# For instance:
TASK = 'MOTOR'
examples_per_task[TASK]
# Out:
# [{'LH': 786}, {'CUE': 786}, {'RH': 786}, {'LF': 783}, {'RF': 785}]

# %% [markdown]
# # 3. Create a dataloader.

# %% [markdown]
# ## a. Data of interest
# First, we need to store in a class the paths of the data samples and their labels.

# %%
def find(tasks:list,task_set:list):
    bin_tasks = []
    for t in tasks:
        if t in task_set:
            bin_tasks.append(True)
        else:
            bin_tasks.append(False)        
    return bin_tasks

class HCP():
    # This class aims to search images of subject(s) / task(s) / contrast(s) (or condition(s)).
    
    def __init__(self, ibc_data):
        # Get the lists of subject names, tasks, contrasts (and conditions) and images.
        # ibc_data : dictionnary obtained by using nilearn fetcher.
        
        self.subjectnames = [image['name'].split('_')[0] for image in ibc_data.images_meta]
        self.tasks = [image['task'] for image in ibc_data.images_meta]
        self.contrasts = [image['contrast_definition'] for image in ibc_data.images_meta]
        self.images = ibc_data.images
        self.meta = ibc_data.images_meta
        self.ffx = ['ffx' not in image['name'].split('_') for image in ibc_data.images_meta]

    def __getsourcetarget__(self, task_set:list, subject_set:list, contrast_set:list, remove_ffx=False):
        # 1) Select the images whose task is in task_set.
        # 2) Select the images whose subject is in subject_set.
        # 3) Select the images whose contrast in in contrast_set.
        # 4) We only select the ap/pa statistic_map (we do not consider the Fixed Effects maps).
        
        # Select the images associated to tasks.
        bin_tasks = find(self.tasks, task_set)
        subjectnames = list(compress(self.subjectnames, bin_tasks))
        tasks = list(compress(self.tasks, bin_tasks))
        contrasts = list(compress(self.contrasts, bin_tasks))
        images = list(compress(self.images, bin_tasks))
        meta = list(compress(self.meta, bin_tasks))
        ffx = list(compress(self.ffx, bin_tasks))

        # Select the images associated subjects.
        bin_subjectnames = find(subjectnames, subject_set)
        subjectnames = list(compress(subjectnames, bin_subjectnames))
        tasks = list(compress(tasks, bin_subjectnames))
        contrasts = list(compress(contrasts, bin_subjectnames))
        images = list(compress(images, bin_subjectnames))
        meta = list(compress(meta, bin_subjectnames))
        ffx = list(compress(ffx, bin_subjectnames))

        # Select the images associated to contrasts.
        bin_contrasts = find(contrasts, contrast_set)
        subjectnames = list(compress(subjectnames, bin_contrasts))
        tasks = list(compress(tasks, bin_contrasts))
        contrasts = list(compress(contrasts, bin_contrasts))
        images = list(compress(images, bin_contrasts))
        meta = list(compress(meta, bin_contrasts))
        ffx = list(compress(ffx, bin_contrasts))
        
        # Keep the ap/pa statistic_map only.
        if remove_ffx:
            subjectnames = list(compress(subjectnames, ffx))
            tasks = list(compress(tasks, ffx))
            contrasts = list(compress(contrasts, ffx))
            images = list(compress(images, ffx))
            meta = list(compress(meta, ffx))

        return images, contrasts, tasks, subjectnames, meta

dataset = HCP(data)

# %%
# images contains the paths to all nii elementary contrast associated with a ap/pa direction (not ffx).
# labels contains the name of the associated classes.
# tasks, subjectnames and meta contain extra-information.
images, labels, tasks, subjectnames, meta = dataset.__getsourcetarget__(np.unique(dataset.tasks), np.unique(dataset.subjectnames), classes)

# %% [markdown]
# ## b. Parcellation
# We can either use the full contrast maps or parcel them into bigger regions before using them. To that end, we compute all parcellations and store them.

# %%
# MNI 152 is a 3D coordinate system for localization in the brain. It is an average taken from 152 healthy individuals.
# ICBM452 -> ICBM152 -> MNI152 -> MNI305 -> Talairach -> Brodmann.
# Current standard MNI template: ICBM152. It is an average of 152 normal MRI scans that have been matched to the MNI305.
mask_mni = fetch_icbm152_brain_gm_mask()

# Glasser is a reference map for regions in the brain. It splits the brain into 360 regions.
glassermasker = NiftiLabelsMasker(labels_img=path_Glasser,mask_img=mask_mni)
glassermasker.fit()

for curmeta in tqdm(meta):
    # Location of the MRI scan on NeuroVault.
    current_url = curmeta['file']
    # Name attributed to the image locally.
    current_newname = os.path.split(curmeta['relative_path'])[1]
    filepath = os.path.join(os.path.join(data_dir, 'neurovault/collection_'+str(collection_id)+'/'), current_newname)


    # Some images were missing. So we manually downloaded them.
    if os.path.exists(filepath):
        #print("File {} already exists".format(filepath))
        pass
    else:
        #print("Downloading file {}...".format(filepath))
        wget.download(url=current_url, out = filepath)
    # Attribute to each image nii a parcellated version stored in a npz file.
    npzfile = os.path.splitext(os.path.splitext(filepath)[0])[0]+'.npz'
    temp_path = os.path.join(os.path.join(data_dir, 'neurovault/collection_'+str(collection_id)+'/npz_files_'+str(collection_id)), current_newname)
    npzfile_second_path = os.path.splitext(os.path.splitext(temp_path)[0])[0]+'.npz'
    if os.path.exists(npzfile):
        #print("Parcellated file {} already exists".format(npzfile))
        pass
    else:       
        #print("Parcellating...")
        X = glassermasker.fit_transform([filepath])
        ## Save the npz file
        savez_compressed(npzfile,X=X)
        savez_compressed(npzfile_second_path,X=X)

    if os.path.exists(npzfile_second_path):
        #print("Parcellated file {} already exists".format(npzfile))
        pass
    else:       
        #print("Parcellating...")
        X = glassermasker.fit_transform([filepath])
        ## Save the npz file
        savez_compressed(npzfile_second_path,X=X)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18052/18052 [00:00<00:00, 62790.84it/s]

# %% [markdown]
# ## d. Splitting the dataset into three datasets: base / validation / novel.
#
# To create a benchmark dataset for few-shot learning, we need to split the classes into three sets: base / validation / novel.
#
# The first two are used to extract general knowledge. The last one to mimic studies with few examples. In our github, we already provide the splits we used in our article.
#
# If you want to generate a new split, you can follow our code and uncomment the last three lines.

# %%
df_gby = df_4337.groupby('contrast_definition').agg({'subject_id':[set,'nunique']})['subject_id'].reset_index()

# %%
df_ = df_gby[df_gby['nunique']!=df_gby['nunique'].max()].reset_index()

# %%
set_subjects = df_.loc[0]['set']
for i in range(len(df_)-1):
    set_subjects = set_subjects.intersection(df_.loc[i+1]['set'])

# %%
print('at least '+str(len(list(set_subjects)))+' common subjects per task')
# Out:
# at least 764 common subjects per task

# %%
np.random.seed(10)
id_train = list(np.random.choice(np.array(list(set(set_subjects))),round(70/100*len(df_4337.subject_id.unique())),replace=False))
id_val = [x for x in list(set_subjects) if x not in id_train]

# %%
nb_total_subject = len(df_4337.subject_id.unique())
np.random.seed(10)
id_train = list(np.random.choice(np.array(list(set(set_subjects))),round(70/100*nb_total_subject),replace=False))
id_val_temp = [x for x in list(set_subjects) if x not in id_train]
id_val = list(np.random.choice(np.array(id_val_temp),round(15/100*nb_total_subject),replace=False))
id_test = [x for x in list(set(subjectnames)) if x not in id_train+id_val]

# %%
df = pd.DataFrame(list(zip(images, labels, tasks, meta,subjectnames)),columns=['Filename','Label','Task','Meta','Subject_id'])
df['Filename'] = df.Filename.apply(lambda x: x.split('/')[-1].split('.')[0])
df_train = df[df['Subject_id'].isin(id_train)]
df_val = df[df['Subject_id'].isin(id_val)]
df_test = df[df['Subject_id'].isin(id_test)]

print('The base set contains ', df_train.Label.nunique(), 'classes.')
print('The validation set contains ', df_val.Label.nunique(), 'classes.')
print('The test set contains ', df_test.Label.nunique(), 'classes.')
print('The base set contains ', len(df_train), 'data samples.')
print('The validation set contains ', len(df_val), 'data samples.')
print('The test set contains ', len(df_test), 'data samples.')
# Out:
# The base set contains  23 classes.
# The validation set contains  23 classes.
# The test set contains  23 classes.
# The base set contains  12673 data samples.
# The validation set contains  2714 data samples.
# The test set contains  2665 data samples.

# %%
if not os.path.exists('splits/split_HCP'):
    os.makedirs('splits/split_HCP')
df_train.to_csv('splits/split_HCP/'+'train.csv',index=False)
df_val.to_csv('splits/split_HCP/'+'val.csv',index=False)
df_test.to_csv('splits/split_HCP/'+'test.csv',index=False)
